# %%
import pandas
print(1)
print(2)
# Out:
# 1
# 2

# %%
df = pandas.read_csv("D:\\Cursos\\Python Mega Course\\Seccion_12\\Files\\temps_today.csv")
df
# Out:
#     st1   st2
# 0  23.2  22.1
# 1  24.0  23.1
# 2  22.1  20.2
# 3  19.1  16.8

# %%
df7 = pandas.read_json("http://pythonhow.com/supermarkets.json")
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df8 = pandas.read_csv("data.txt")
df8
# Out:
#    1     3666 21st St  San Francisco          CA 94114             USA  \
# 0  2   735 Dolores St  San Francisco          CA 94119             USA
# 1  3      332 Hill St  San Francisco  California 94114             USA
# 2  4     3995 23rd St  San Francisco          CA 94114  USA;Ben's Shop
# 3  5  1056 Sanchez St  San Francisco        California             USA
# 4  6  551 Alvarado St  San Francisco          CA 94114             USA
#
#         Madeira     8
# 0   Bready Shop  15.0
# 1   Super River  25.0
# 2            10   NaN
# 3       Sanchez  12.0
# 4    Richvalley  20.0

# %%
df8 = pandas.read_csv("data.txt", header = None)
df8
# Out:
#    0                1              2                 3               4  \
# 0  1     3666 21st St  San Francisco          CA 94114             USA
# 1  2   735 Dolores St  San Francisco          CA 94119             USA
# 2  3      332 Hill St  San Francisco  California 94114             USA
# 3  4     3995 23rd St  San Francisco          CA 94114  USA;Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California             USA
# 5  6  551 Alvarado St  San Francisco          CA 94114             USA
#
#               5     6
# 0       Madeira   8.0
# 1   Bready Shop  15.0
# 2   Super River  25.0
# 3            10   NaN
# 4       Sanchez  12.0
# 5    Richvalley  20.0

# %%
df8.columns= {"Name", "Address", "City", "ZIP", "Country", "ID", "Employees"}
df8
# Out:
#    Name        Employees           City           Address             ZIP  \
# 0     1     3666 21st St  San Francisco          CA 94114             USA
# 1     2   735 Dolores St  San Francisco          CA 94119             USA
# 2     3      332 Hill St  San Francisco  California 94114             USA
# 3     4     3995 23rd St  San Francisco          CA 94114  USA;Ben's Shop
# 4     5  1056 Sanchez St  San Francisco        California             USA
# 5     6  551 Alvarado St  San Francisco          CA 94114             USA
#
#              ID  Country
# 0       Madeira      8.0
# 1   Bready Shop     15.0
# 2   Super River     25.0
# 3            10      NaN
# 4       Sanchez     12.0
# 5    Richvalley     20.0

# %%
df8.set_index("ID")
# Out:
#               Name        Employees           City           Address  \
# ID
# Madeira          1     3666 21st St  San Francisco          CA 94114
# Bready Shop      2   735 Dolores St  San Francisco          CA 94119
#  Super River     3      332 Hill St  San Francisco  California 94114
# 10               4     3995 23rd St  San Francisco          CA 94114
# Sanchez          5  1056 Sanchez St  San Francisco        California
# Richvalley       6  551 Alvarado St  San Francisco          CA 94114
#
#                          ZIP  Country
# ID
# Madeira                  USA      8.0
# Bready Shop              USA     15.0
#  Super River             USA     25.0
# 10            USA;Ben's Shop      NaN
# Sanchez                  USA     12.0
# Richvalley               USA     20.0

# %%
df8
# Out:
#    Name        Employees           City           Address             ZIP  \
# 0     1     3666 21st St  San Francisco          CA 94114             USA
# 1     2   735 Dolores St  San Francisco          CA 94119             USA
# 2     3      332 Hill St  San Francisco  California 94114             USA
# 3     4     3995 23rd St  San Francisco          CA 94114  USA;Ben's Shop
# 4     5  1056 Sanchez St  San Francisco        California             USA
# 5     6  551 Alvarado St  San Francisco          CA 94114             USA
#
#              ID  Country
# 0       Madeira      8.0
# 1   Bready Shop     15.0
# 2   Super River     25.0
# 3            10      NaN
# 4       Sanchez     12.0
# 5    Richvalley     20.0

# %%
df9 = df8.set_index("ID")
df9
# Out:
#               Name        Employees           City           Address  \
# ID
# Madeira          1     3666 21st St  San Francisco          CA 94114
# Bready Shop      2   735 Dolores St  San Francisco          CA 94119
#  Super River     3      332 Hill St  San Francisco  California 94114
# 10               4     3995 23rd St  San Francisco          CA 94114
# Sanchez          5  1056 Sanchez St  San Francisco        California
# Richvalley       6  551 Alvarado St  San Francisco          CA 94114
#
#                          ZIP  Country
# ID
# Madeira                  USA      8.0
# Bready Shop              USA     15.0
#  Super River             USA     25.0
# 10            USA;Ben's Shop      NaN
# Sanchez                  USA     12.0
# Richvalley               USA     20.0

# %%
df8.set_index("Address", inplace=True)
df8
# Out:
#                   Name        Employees           City             ZIP  \
# Address
# CA 94114             1     3666 21st St  San Francisco             USA
# CA 94119             2   735 Dolores St  San Francisco             USA
# California 94114     3      332 Hill St  San Francisco             USA
# CA 94114             4     3995 23rd St  San Francisco  USA;Ben's Shop
# California           5  1056 Sanchez St  San Francisco             USA
# CA 94114             6  551 Alvarado St  San Francisco             USA
#
#                             ID  Country
# Address
# CA 94114               Madeira      8.0
# CA 94119           Bready Shop     15.0
# California 94114   Super River     25.0
# CA 94114                    10      NaN
# California             Sanchez     12.0
# CA 94114            Richvalley     20.0

# %%
df8.set_index("Name", inplace=True, drop=False)
df8
# Out:
#       Name        Employees           City             ZIP            ID  \
# Name
# 1        1     3666 21st St  San Francisco             USA       Madeira
# 2        2   735 Dolores St  San Francisco             USA   Bready Shop
# 3        3      332 Hill St  San Francisco             USA   Super River
# 4        4     3995 23rd St  San Francisco  USA;Ben's Shop            10
# 5        5  1056 Sanchez St  San Francisco             USA       Sanchez
# 6        6  551 Alvarado St  San Francisco             USA    Richvalley
#
#       Country
# Name
# 1         8.0
# 2        15.0
# 3        25.0
# 4         NaN
# 5        12.0
# 6        20.0

# %%
df7 = df7.set_index("Address")
df7
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df7.loc["735 Dolores St": "332 Hill St", "Country": "ID"]
# Out:
#                Country  Employees  ID
# Address
# 735 Dolores St     USA         15   2
# 332 Hill St        USA         25   3

# %%
df7.loc[:, "Country": "ID"]
# Out:
#                 Country  Employees  ID
# Address
# 3666 21st St        USA          8   1
# 735 Dolores St      USA         15   2
# 332 Hill St         USA         25   3
# 3995 23rd St        USA         10   4
# 1056 Sanchez St     USA         12   5
# 551 Alvarado St     USA         20   6

# %%
df7.loc["332 Hill St", "Country"]
# Out:
# 'USA'

# %%
list(df7.loc[:, "Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df7
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df7.iloc[1:4,1:4]
# Out:
#                Country  Employees  ID
# Address
# 735 Dolores St     USA         15   2
# 332 Hill St        USA         25   3
# 3995 23rd St       USA         10   4

# %%
df7.iloc[4,1:4]
# Out:
# Country      USA
# Employees     12
# ID             5
# Name: 1056 Sanchez St, dtype: object

# %%
df7.drop("332 Hill st", 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df7.drop("332 Hill st", 0)
#
# TypeError: DataFrame.drop() takes from 1 to 2 positional arguments but 3 were given

# %%
pandas.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame
